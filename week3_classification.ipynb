# %% [markdown]
# ### Classification Task
# - Classifying tropical fruit types from 34 features extracted from the images of fruits.
# - Types present: {Barhee, Deglet Nour, Sukkary, Rotab Mozafati, Ruthana, Safawi, and Sagai}
# - Use-case: Given the 34 features from a new image of a fruit and pass it to the classifier, the classifier will be able to tell its type.

# %% [markdown]
# ### Question 1
# - How many samples are there in the dataset?
# - How many features are there per sample, excluding the class/type label?
# - Print the number of unique classes (i.e., fruit types), list the class names, and their frequency distribution.

# %%
import pandas as pd

# There are 898 samples/rows
# There are 35 features/columns
df = pd.read_excel('datasets/Date_Fruit_Datasets.xlsx',sheet_name="Date_Fruit_Datasets")
df.head(n=5)
# Out:
#      AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0  422163   2378.908    837.8484    645.6693        0.6373  733.1539
# 1  338136   2085.144    723.8198    595.2073        0.5690  656.1464
# 2  526843   2647.394    940.7379    715.3638        0.6494  819.0222
# 3  416063   2351.210    827.9804    645.2988        0.6266  727.8378
# 4  347562   2160.354    763.9877    582.8359        0.6465  665.2291
#
#    SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ...  KurtosisRR  KurtosisRG  \
# 0    0.9947       424428  0.7831        1.2976  ...      3.2370      2.9574
# 1    0.9974       339014  0.7795        1.2161  ...      2.6228      2.6350
# 2    0.9962       528876  0.7657        1.3150  ...      3.7516      3.8611
# 3    0.9948       418255  0.7759        1.2831  ...      5.0401      8.6136
# 4    0.9908       350797  0.7569        1.3108  ...      2.7016      2.9761
#
#    KurtosisRB    EntropyRR    EntropyRG    EntropyRB  ALLdaub4RR  ALLdaub4RG  \
# 0      4.2287 -59191263232 -50714214400 -39922372608     58.7255     54.9554
# 1      3.1704 -34233065472 -37462601728 -31477794816     50.0259     52.8168
# 2      4.7192 -93948354560 -74738221056 -60311207936     65.4772     59.2860
# 3      8.2618 -32074307584 -32060925952 -29575010304     43.3900     44.1259
# 4      4.4146 -39980974080 -35980042240 -25593278464     52.7743     50.9080
#
#    ALLdaub4RB  Class
# 0     47.8400  BERHI
# 1     47.8315  BERHI
# 2     51.9378  BERHI
# 3     41.1882  BERHI
# 4     42.6666  BERHI
#
# [5 rows x 35 columns]

# %%
# number of samples
df.shape
# Out:
# (898, 35)

# %%
# The nunique() method returns the number of unique values for each column.
# There are 7 unique values in the "Class" column
df['Class'].nunique()
# Out:
# 7

# %%
# list of unique values in 'Class' column
df['Class'].unique()
# Out:
# array(['BERHI', 'DEGLET', 'DOKOL', 'IRAQI', 'ROTANA', 'SAFAVI', 'SOGAY'],
#       dtype=object)

# %%
# Class distribution
df['Class'].value_counts()
# Out:
# Class
# DOKOL     204
# SAFAVI    199
# ROTANA    166
# DEGLET     98
# SOGAY      94
# IRAQI      72
# BERHI      65
# Name: count, dtype: int64

# %% [markdown]
# ### Question 2
# - List mean, stdev, min, max of each of the features in the dataset
#
# - The **describe()** method returns description of the data in the DataFrame.
#     - If the DataFrame contains numerical data, the description contains these information for each column:
#         - count - The number of not-empty values.
#         - mean - The average (mean) value.
#         - std - The standard deviation.
#         - min - the minimum value.
#         - 25% - The 25% percentile*.
#         - 50% - The 50% percentile*.
#         - 75% - The 75% percentile*.
#         - max - the maximum value.

# %%
df.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  ...  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000  ...
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102  ...
# std    119.593888    0.018157  108815.656947    0.053745     17.820778  ...
# min     50.298400    0.836600    2257.000000    0.512300      1.065300  ...
# 25%    513.317075    0.978825  210022.750000    0.705875      1.373725  ...
# 50%    638.140950    0.987300  327207.000000    0.746950      1.524150  ...
# 75%    697.930525    0.991800  388804.000000    0.775850      1.674750  ...
# max    833.827900    0.997400  552598.000000    0.856200    535.525700  ...
#
#            SkewRB  KurtosisRR  KurtosisRG  KurtosisRB     EntropyRR  \
# count  898.000000  898.000000  898.000000  898.000000  8.980000e+02
# mean     0.250518    4.247845    5.110894    3.780928 -3.185021e+10
# std      0.632918    2.892357    3.745463    2.049831  2.037241e+10
# min     -1.029100    1.708200    1.607600    1.767200 -1.091224e+11
# 25%     -0.196950    2.536625    2.508850    2.577275 -4.429444e+10
# 50%      0.135550    3.069800    3.127800    3.080700 -2.826156e+10
# 75%      0.593950    4.449850    7.320400    4.283125 -1.460482e+10
# max      3.092300   26.171100   26.736700   32.249500 -1.627316e+08
#
#           EntropyRG     EntropyRB  ALLdaub4RR  ALLdaub4RG  ALLdaub4RB
# count  8.980000e+02  8.980000e+02  898.000000  898.000000  898.000000
# mean  -2.901860e+10 -2.771876e+10   50.082888   48.805681   48.098393
# std    1.712952e+10  1.484137e+10   16.063125   14.125911   10.813862
# min   -9.261697e+10 -8.747177e+10   15.191100   20.524700   22.130000
# 25%   -3.894638e+10 -3.564534e+10   38.224425   38.654525   39.250725
# 50%   -2.620990e+10 -2.392928e+10   53.841300   50.337800   49.614100
# 75%   -1.433105e+10 -1.660367e+10   63.063350   59.573600   56.666675
# max   -5.627727e+08 -4.370435e+08   79.828900   83.064900   74.104600
#
# [8 rows x 34 columns]

# %%
# display_opt: Creates a dictionary that stores the current settings for display.max_rows and display.max_columns
# pd.get_option('display.max_rows') and pd.get_option('display.max_columns') are used to retrieve the current 
# settings for the maximum number of rows and columns to display
display_opt = {'display.max_rows': pd.get_option('display.max_rows'),
               'display.max_columns': pd.get_option('display.max_columns'),
            }

# %%
# Sets the display.max_columns option to None - pandas will display all columns of the DataFrame without truncating them
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY  \
# count     898.000000   898.000000   898.000000  898.000000    898.000000
# mean   298295.207127  2057.660953   750.811994  495.872785      0.737468
# std    107245.205337   410.012459   144.059326  114.268917      0.088727
# min      1987.000000   911.828000   336.722700    2.283200      0.344800
# 25%    206948.000000  1726.091500   641.068650  404.684375      0.685625
# 50%    319833.000000  2196.345450   791.363400  495.054850      0.754700
# 75%    382573.000000  2389.716575   858.633750  589.031700      0.802150
# max    546063.000000  2811.997100  1222.723000  766.453600      1.000000
#
#           EQDIASQ    SOLIDITY    CONVEX_AREA      EXTENT  ASPECT_RATIO  \
# count  898.000000  898.000000     898.000000  898.000000    898.000000
# mean   604.577938    0.981840  303845.592428    0.736267      2.131102
# std    119.593888    0.018157  108815.656947    0.053745     17.820778
# min     50.298400    0.836600    2257.000000    0.512300      1.065300
# 25%    513.317075    0.978825  210022.750000    0.705875      1.373725
# 50%    638.140950    0.987300  327207.000000    0.746950      1.524150
# 75%    697.930525    0.991800  388804.000000    0.775850      1.674750
# max    833.827900    0.997400  552598.000000    0.856200    535.525700
#
#         ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  SHAPEFACTOR_2  SHAPEFACTOR_3  \
# count  898.000000   898.000000     898.000000     898.000000     898.000000
# mean     0.857720     0.807190       0.003428       0.001794       0.655420
# std      0.070839     0.062175       0.020456       0.000428       0.094314
# min      0.004800     0.041100       0.001700       0.001100       0.001700
# 25%      0.827750     0.768050       0.002200       0.001500       0.589975
# 50%      0.867750     0.804950       0.002600       0.001600       0.647950
# 75%      0.899500     0.848875       0.003200       0.002075       0.720625
# max      0.977300     0.968100       0.615400       0.004300       0.937300
#
#        SHAPEFACTOR_4      MeanRR      MeanRG      MeanRB    StdDevRR  \
# count     898.000000  898.000000  898.000000  898.000000  898.000000
# mean        0.988680  100.165885   97.609401   96.194889   29.047436
# std         0.020473   32.126549   28.251801   21.627409    6.306931
# min         0.756800   30.382600   41.048000   44.256900    7.303800
# 25%         0.989300   76.448000   77.306125   78.502375   24.901525
# 50%         0.993600  107.682450  100.676000   99.225600   29.709450
# 75%         0.996400  126.127450  119.159600  113.332250   33.274375
# max         0.999500  159.649400  166.135400  148.211400   48.571200
#
#          StdDevRG    StdDevRB      SkewRR      SkewRG      SkewRB  KurtosisRR  \
# count  898.000000  898.000000  898.000000  898.000000  898.000000  898.000000
# mean    26.383362   26.148330    0.089266    0.564139    0.250518    4.247845
# std      5.462164    4.905078    0.943285    1.039813    0.632918    2.892357
# min      8.655700    5.148600   -1.724200   -1.834400   -1.029100    1.708200
# 25%     22.289650   22.890975   -0.549900   -0.230200   -0.196950    2.536625
# 50%     25.638300   26.469000   -0.162700    0.243750    0.135550    3.069800
# 75%     29.905325   29.482375    0.471025    1.406550    0.593950    4.449850
# max     45.510700   42.422800    3.223600    3.697100    3.092300   26.171100
#
#        KurtosisRG  KurtosisRB     EntropyRR     EntropyRG     EntropyRB  \
# count  898.000000  898.000000  8.980000e+02  8.980000e+02  8.980000e+02
# mean     5.110894    3.780928 -3.185021e+10 -2.901860e+10 -2.771876e+10
# std      3.745463    2.049831  2.037241e+10  1.712952e+10  1.484137e+10
# min      1.607600    1.767200 -1.091224e+11 -9.261697e+10 -8.747177e+10
# 25%      2.508850    2.577275 -4.429444e+10 -3.894638e+10 -3.564534e+10
# 50%      3.127800    3.080700 -2.826156e+10 -2.620990e+10 -2.392928e+10
# 75%      7.320400    4.283125 -1.460482e+10 -1.433105e+10 -1.660367e+10
# max     26.736700   32.249500 -1.627316e+08 -5.627727e+08 -4.370435e+08
#
#        ALLdaub4RR  ALLdaub4RG  ALLdaub4RB
# count  898.000000  898.000000  898.000000
# mean    50.082888   48.805681   48.098393
# std     16.063125   14.125911   10.813862
# min     15.191100   20.524700   22.130000
# 25%     38.224425   38.654525   39.250725
# 50%     53.841300   50.337800   49.614100
# 75%     63.063350   59.573600   56.666675
# max     79.828900   83.064900   74.104600

# %% [markdown]
# ### Question 3
# - Shuffle the data samples.

# %%
df_shuffled = df.sample(frac=1)
df_shuffled.head()
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 109  233279  1812.4000    649.0758    459.3955        0.7064  544.9955
# 555  445394  2482.9741    880.8090    647.2557        0.6782  753.0560
# 477  293332  2079.7439    706.2109    545.3020        0.6354  611.1317
# 444  398202  2425.7310    872.2453    597.3273        0.7287  712.0439
# 415  442441  2480.0330    872.0508    653.3934        0.6623  750.5554
#
#      SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# 109    0.9865       236470  0.7785        1.4129     0.8924       0.8396
# 555    0.9897       450019  0.7901        1.3608     0.9078       0.8550
# 477    0.9547       307255  0.7069        1.2951     0.8522       0.8654
# 444    0.9734       409088  0.7088        1.4602     0.8504       0.8163
# 415    0.9869       448328  0.7056        1.3346     0.9040       0.8607
#
#      SHAPEFACTOR_1  SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4    MeanRR  \
# 109         0.0028         0.0020         0.7050         0.9961  113.9909
# 555         0.0020         0.0015         0.7310         0.9947  122.3809
# 477         0.0024         0.0019         0.7489         0.9698  127.1838
# 444         0.0022         0.0015         0.6664         0.9731  102.6821
# 415         0.0020         0.0015         0.7408         0.9887   68.1102
#
#        MeanRG    MeanRB  StdDevRR  StdDevRG  StdDevRB  SkewRR  SkewRG  SkewRB  \
# 109  105.3298  107.9339   36.4504   38.6125   29.3920 -0.1454  0.2381 -0.1816
# 555  115.1930  112.3489   38.0114   35.9918   35.7982 -0.4208 -0.1767 -0.3684
# 477  117.9342  110.6929   35.3156   34.5379   30.9952  0.0100  0.0151 -0.0814
# 444   96.8168  100.1137   28.7349   28.4511   28.3914 -0.0531  0.1404 -0.0175
# 415   74.4832   75.8449   31.3754   30.0789   34.5218  2.1805  2.4854  2.0979
#
#      KurtosisRR  KurtosisRG  KurtosisRB    EntropyRR    EntropyRG  \
# 109      2.2934      1.9759      2.4983 -32555407360 -28394031104
# 555      2.1858      2.0894      2.2953 -72167956480 -63271403520
# 477      2.2471      2.3148      2.3854 -50616311808 -43299790848
# 444      2.5380      2.6608      2.5772 -42909077504 -38047789056
# 415     11.3266     12.5314      9.5022 -22502656000 -25999837184
#
#        EntropyRB  ALLdaub4RR  ALLdaub4RG  ALLdaub4RB   Class
# 109 -27923378176     56.9895     52.6629     53.9634  DEGLET
# 555 -60120936448     61.1908     57.5982     56.1762  ROTANA
# 477 -37318025216     63.5886     58.9688     55.3470  ROTANA
# 444 -40675459072     51.3432     48.4122     50.0592  ROTANA
# 415 -28411379712     34.0594     37.2474     37.9290   IRAQI

# %% [markdown]
# ### Question 4
# - Split the dataset into training (80%) and test (20%)
#     - Splitting your dataset into training and testing sets allows you to evaluate your model's performance accurately

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_shuffled.iloc[:,:-1]
y = df_shuffled.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %% [markdown]
# ### Question 5
# - Scale all independent features.
#     - **Scaling** data into new values makes it easier to compare, especially when the data is in different units of measure.
#     - **Data scaling** is the process of transforming the values of the features of a dataset till they are within a specific range, e.g. 0 to 1 or -1 to 1. This is to ensure that no single feature dominates the distance calculations in an algorithm, and can help to improve the performance of the algorithm
#     - **Data transformation** ensures that all of your metrics are uniform, which allows for better analysis and stronger insights.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)

# features = x
# label =  y
# the features are all the columns besides class 
# because this is the information needed in order to predict/classify the class
# train_set_x = training_set.drop(columns=['Class'])
# test_set_x = test_set.drop(columns=['Class'])
# # initialize the scaler
# scaler = StandardScaler()
# # fit the scaler to the sets
# scaler.fit(train_set_x)
# # transform the numerical data
# scaled_training_x = scaler.transform(train_set_x)
# scaled_testing_x = scaler.transform(test_set_x)

# print(scaled_training_x.shape)
# print(scaled_testing_x.shape)
# Out:
# StandardScaler()

# %%
# transform the scaled X training set
X_train_scaled = scaler.transform(X_train)

# %% [markdown]
# ### Question 6
# - Build a classifier with the training set.
# - "**Classification** is a supervised machine learning method where the model tries to predict the correct label of a given input data.
# - In classification, the model is fully trained using the training data, and then it is evaluated on test data before being used to perform prediction on new unseen data."
# - A **label** is a column used for supervised learning
# - **Features** are the values/set of columns that a supervised model uses to predict the label. The **label** is the "answer," or the value we want the model to predict
# - EX: Spam email detection: Given a set of scam and non-scam emails the model is tested on how well it can label the scam emails

# %% [markdown]
# #### Using KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_scaled,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# #### Question 7
# - Predict class label of just one sample picked from the test set

# %%
X_test.shape
# Out:
# (180, 34)

# %%
import numpy as np
a_sample = np.array(X_test.iloc[0,:])
print(a_sample.shape)
a_sample = a_sample.ravel().reshape(1,-1)
a_sample.shape
# Out:
# (34,)
# (1, 34)

# %%
a_sample_scaled = scaler.transform(a_sample)
y_pred = knn.predict(a_sample)
y_pred
# Out:
# /Users/natalienguyen/venv-machine-learning/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array(['ROTANA'], dtype=object)

# %% [markdown]
# ### Question 8
# - Evaluate the model performance based on the test set

# %%
def cm_scores(y_actual, y_pred):
    y_actual = np.array(y_actual)
    TP = 0
    FP = 0 
    TN = 0 
    FN = 0

    for i in range(len(y_pred)): 
        if y_actual[i]==y_pred[i]==1:
           TP += 1
        if y_pred[i]==1 and y_actual[i]==0:
           FP += 1
        if y_actual[i]==y_pred[i]==0:
           TN += 1
        if y_pred[i]==0 and y_actual[i]==1:
           FN += 1

    return (TN, FP, FN, TP)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
y_pred = knn.predict(X_test_scaled)

# %%
y_test
# Out:
# 336     DOKOL
# 276     DOKOL
# 221     DOKOL
# 848     SOGAY
# 451    ROTANA
#         ...
# 726    SAFAVI
# 466    ROTANA
# 463    ROTANA
# 509    ROTANA
# 28      BERHI
# Name: Class, Length: 180, dtype: object

# %%
y_pred
# Out:
# array(['DOKOL', 'DOKOL', 'DOKOL', 'SOGAY', 'ROTANA', 'DOKOL', 'SOGAY',
#        'DEGLET', 'DEGLET', 'DOKOL', 'ROTANA', 'DEGLET', 'SAFAVI',
#        'DEGLET', 'DEGLET', 'SOGAY', 'DOKOL', 'SAFAVI', 'SAFAVI', 'DOKOL',
#        'SAFAVI', 'ROTANA', 'BERHI', 'ROTANA', 'IRAQI', 'IRAQI', 'IRAQI',
#        'ROTANA', 'SAFAVI', 'IRAQI', 'IRAQI', 'DOKOL', 'DOKOL', 'SAFAVI',
#        'ROTANA', 'DOKOL', 'SOGAY', 'DOKOL', 'ROTANA', 'SOGAY', 'ROTANA',
#        'DOKOL', 'SOGAY', 'IRAQI', 'BERHI', 'SOGAY', 'ROTANA', 'DOKOL',
#        'ROTANA', 'DEGLET', 'DOKOL', 'DOKOL', 'ROTANA', 'IRAQI', 'DOKOL',
#        'SOGAY', 'SAFAVI', 'DOKOL', 'ROTANA', 'ROTANA', 'DOKOL', 'ROTANA',
#        'DEGLET', 'DEGLET', 'DOKOL', 'SAFAVI', 'DOKOL', 'ROTANA', 'DEGLET',
#        'BERHI', 'DOKOL', 'ROTANA', 'IRAQI', 'DEGLET', 'ROTANA', 'SAFAVI',
#        'DOKOL', 'ROTANA', 'DOKOL', 'BERHI', 'SAFAVI', 'ROTANA', 'DEGLET',
#        'SAFAVI', 'SAFAVI', 'IRAQI', 'SOGAY', 'SAFAVI', 'DOKOL', 'DEGLET',
#        'SAFAVI', 'ROTANA', 'SAFAVI', 'SAFAVI', 'BERHI', 'SAFAVI', 'DOKOL',
#        'SAFAVI', 'ROTANA', 'DEGLET', 'SOGAY', 'ROTANA', 'SAFAVI',
#        'DEGLET', 'SOGAY', 'SAFAVI', 'SAFAVI', 'DOKOL', 'ROTANA', 'DOKOL',
#        'SAFAVI', 'ROTANA', 'DOKOL', 'SAFAVI', 'DOKOL', 'ROTANA', 'DOKOL',
#        'DEGLET', 'SOGAY', 'ROTANA', 'SAFAVI', 'IRAQI', 'SAFAVI', 'SOGAY',
#        'ROTANA', 'SAFAVI', 'SOGAY', 'ROTANA', 'IRAQI', 'DEGLET', 'SAFAVI',
#        'DEGLET', 'ROTANA', 'SAFAVI', 'ROTANA', 'SOGAY', 'BERHI', 'BERHI',
#        'BERHI', 'SAFAVI', 'IRAQI', 'SAFAVI', 'DOKOL', 'IRAQI', 'SOGAY',
#        'DOKOL', 'ROTANA', 'DEGLET', 'DOKOL', 'IRAQI', 'BERHI', 'BERHI',
#        'SAFAVI', 'DEGLET', 'SAFAVI', 'BERHI', 'SAFAVI', 'DOKOL', 'DOKOL',
#        'SAFAVI', 'SAFAVI', 'BERHI', 'SOGAY', 'SAFAVI', 'ROTANA', 'IRAQI',
#        'DOKOL', 'ROTANA', 'DOKOL', 'SAFAVI', 'ROTANA', 'SOGAY', 'ROTANA',
#        'DOKOL', 'DOKOL', 'SAFAVI', 'ROTANA', 'ROTANA', 'ROTANA', 'BERHI'],
#       dtype=object)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        BERHI       0.62      0.73      0.67        11
#       DEGLET       0.74      0.88      0.80        16
#        DOKOL       0.95      0.90      0.93        41
#        IRAQI       0.87      0.81      0.84        16
#       ROTANA       0.92      1.00      0.96        35
#       SAFAVI       0.97      0.97      0.97        38
#        SOGAY       0.83      0.65      0.73        23
#
#     accuracy                           0.88       180
#    macro avg       0.84      0.85      0.84       180
# weighted avg       0.89      0.88      0.88       180

# %% [markdown]
# ## Process of Building an Effection Classification Model
# ### Step 1: Define the Problem
# - Understand what you want to accomplish with your classification model.
# - For ex, if the data set consists of spam emails and non-spam emails, the goal might be scam email classification
#
# ### Step 2: Gather and Preprocess the Data
# - Shuffle the data
# - Split it into a training and testing set
# - only fit the TRAINING set
# - BOTH the sets will be transformed and scaled
# - x is the independent variable
# - y is the dependent
#
# ### Step 3: Feature Selection and Engineering
# - Features are going to be the columns that a supervised model uses to predict the label (Emails: Spam and non-spam emails)
# - A label is the column that the supervised model is trying to predict (Class: spam or non-spam)
# - X-axis = features
# - Y-axis = label
#
# ### Step 4: Choose a model (Supervised learning)
# - There are many models to choose from:
#     - Random Forest
#     - Support Vector Machines
#     - Neural Networks
#     - Gradient Boosting
#     - Logistic Regression
#     - Decision Trees
#     - etc.
# - Fit the scaled training set(X) and encoded training set(Y) for the x and y values
# - predict the model with the scaled TEST set (x)
#
# ### Step 5: Evaluate the Model
# - Calculate the report accuracy, precision, recall, f1-score, false-discovery rate, matthews correlation coefficient of the set.
#
#
# - How to evaluate a REGRESSION model
#     - Mean squared error (MSE)
#         - MSE = np.sum((test_y_set - pred)**2)/len(test_set_y)
#     - Root mean sqaured error
#         - RMSE = bp.sqrt(MSE)
#     - or use the libraries
#         - from sklearn.metrics import mean_squared_error
#         - from sklearn.metrics import r2_score
#         - RMSE = np.sqrt(mean_squared_error(test_set_y, pred))
#     - Mean Absolute Error (MAE)
#         - least absolute differences = (test_set_y - pred)
#         - MAE = np.sum(np.abs(test_set_y - pred))/len(test_set_y)
#         - or use the library
#     - R2 Score
#         - 1 - (your model/mean model )
#         - your_model = np.sum((test_set_y)**2)
#         - mean_model = np.mean((test_set_y -np.mean(test_set_y)) **2)
#         - mean model = the higher the number(closer to 1), the lower R2 is
#                     = the lower(0-1), the higher R2 is
#                     = less than 0, worst
#         - R2 = (1 - (your_model/ mean_model))
#         - or import the library r2_score
#         - best R2 score is 1
#
#     - Adjusted R2 score only applies if you have many independent features
#         - 1 - ((1-R2)(n-1)/ (n-p-1))
#         - P = number of independent features
#         - n = num of samples
#         - if tuple is (24016,1)
#         - p = 1
#         - n = 24016
#     - Regression line
#         - y = f(x1,x2)
